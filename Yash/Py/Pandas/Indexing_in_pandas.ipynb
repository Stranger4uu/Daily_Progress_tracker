# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30, 40, 50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s[0]
# Out:
# np.int64(10)

# %%
s[0:3]
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# ilocc -> location based indexing

# %%
s.iloc[3]
# Out:
# np.int64(40)
